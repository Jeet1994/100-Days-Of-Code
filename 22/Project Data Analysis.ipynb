# %%
import pandas as pd

# %%
df = pd.read_excel('C:\\Users\daspr\Downloads\ROData.xlsx')
# Out:
# C:\Users\daspr\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.head()
# Out:
#    SNo   RO Code                          RO Name Last Data Recvd on (Date)  \
# 0  1.0  160683.0         AUTO FUEL SERVICE CENTRE                24-06-2022
# 1  2.0  316084.0            AJINKYARAJE PETROLEUM                24-06-2022
# 2  3.0  126314.0            Kale Service Station.                24-06-2022
# 3  4.0  133961.0        KTS NAGAMANICKAM CHETTIAR                24-06-2022
# 4  5.0  270292.0  SARAVANA AGENCIES (LOCK NO.243)                24-06-2022
#
#   Last Data Recvd on (Time) Last Known Mode of Commn  \
# 0                  11:30:06                    Other
# 1                  11:30:06                    Other
# 2                  11:30:06                    Other
# 3                  11:30:06                    Other
# 4                  11:30:06                    Other
#
#   LAST FCC TRANSACTION DATE LAST FCC TRANSACTION TIME Automation Vendor Phase  \
# 0                24-06-2022                  11:30:00              ATOS    VI
# ...

# %%
df.tail()
# Out:
#            SNo   RO Code                              RO Name  \
# 33204  33205.0  311522.0       NATIONAL SERVICE STATION ADHOC
# 33205  33206.0  154827.0         RAMAGANGA AREA DEV.AUTHORITY
# 33206  33207.0  123440.0                 MADANLAL HARINARAYAN
# 33207  33208.0  191577.0  S MUNIRATHNAM NAIDU FILLING STATION
# 33208  33209.0  289373.0       SAYED BROTHERS FILLING STATION
#
#       Last Data Recvd on (Date) Last Data Recvd on (Time)  \
# 33204                20-11-2018                  15:24:53
# 33205                02-11-2018                  15:32:55
# 33206                06-10-2018                  15:25:10
# 33207                01-09-2018                  13:26:20
# 33208                28-06-2018                  16:28:12
#
#       Last Known Mode of Commn LAST FCC TRANSACTION DATE  \
# 33204                    Other                20-11-2018
# 33205                    Other                02-11-2018
# 33206                    Other                06-10-2018
# ...

# %%
df.shape
# Out:
# (33209, 28)

# %%
df.dtypes
# Out:
# SNo                             float64
# RO Code                         float64
# RO Name                          object
# Last Data Recvd on (Date)        object
# Last Data Recvd on (Time)        object
# Last Known Mode of Commn         object
# LAST FCC TRANSACTION DATE        object
# LAST FCC TRANSACTION TIME        object
# Automation Vendor                object
# Phase                            object
# BOS Version                      object
# FCC Version                      object
# SVM Upgrade Date                 object
# Date of Initialization           object
# VSAT VENDOR                      object
# ITPS Vendor 1                    object
# ITPS Vendor 2                    object
# VSAT INSTALLATION DATE           object
# VSAT INTEGRATION DATE            object
# Last Communication over VSAT     object
# SAT STATUS                       object
# SAT DATE                         object
# SAP STATUS                       object
# ...

# %%
df.count()
# Out:
# SNo                             33209
# RO Code                         33209
# RO Name                         33209
# Last Data Recvd on (Date)       33209
# Last Data Recvd on (Time)       33209
# Last Known Mode of Commn        33209
# LAST FCC TRANSACTION DATE       33209
# LAST FCC TRANSACTION TIME       33209
# Automation Vendor               33209
# Phase                           33209
# BOS Version                     33057
# FCC Version                     33059
# SVM Upgrade Date                33059
# Date of Initialization          32756
# VSAT VENDOR                     28104
# ITPS Vendor 1                   24984
# ITPS Vendor 2                    2294
# VSAT INSTALLATION DATE          27845
# VSAT INTEGRATION DATE           27185
# Last Communication over VSAT    18490
# SAT STATUS                      33209
# SAT DATE                        32042
# SAP STATUS                      33209
# Divisional Office               33209
# Divisional Office Name          33209
# ...
